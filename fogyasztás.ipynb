# %%
import pandas as pd

# %%
df1 = pd.read_csv('TEMPO_mezfogyasztas-regio_csv.csv')

# %%
df1 = df1.drop('ABF - Principalele produse alimentare ale consumului uman', axis = 1)
df1 = df1.drop(' Unitati de masura', axis = 1)

# %%
df1[' Perioade'] = df1[' Perioade'].str.extract('(\d+)')

# %% [markdown]
# csak az év és az átlagos fogyasztás teljesen

# %%
df = df1[(df1[' ABF - Principalele categorii sociale'] == ' Total') &
                 (df1[' Macroregiuni si regiuni de dezvoltare'] == ' TOTAL')]

# %%
df = df.drop(' ABF - Principalele categorii sociale', axis = 1)
df = df.drop(' Macroregiuni si regiuni de dezvoltare', axis = 1)

# %%
df.rename(columns={' Perioade': 'Év'}, inplace=True)
df.rename(columns={' Valoare': 'Átlagos havi fogyasztás (kg)'}, inplace=True)

# %%
df['Év'] = df['Év'].astype(int)

# %%
df.dtypes
# Out:
# Év                                int64
# Átlagos havi fogyasztás (kg)    float64
# dtype: object

# %%
df.to_excel('fogyasztas.xlsx')
df.to_csv('fogyasztas.csv')

# %% [markdown]
# atlagos fogyasztás makroregiokra

# %%
df = df1[(df1[' ABF - Principalele categorii sociale'] == ' Total') &
                 (df1[' Macroregiuni si regiuni de dezvoltare'] != ' TOTAL')]

# %%
df = df.drop(' ABF - Principalele categorii sociale', axis = 1)

# %%
df.rename(columns={' Macroregiuni si regiuni de dezvoltare': 'Makrorégiók'}, inplace=True)
df.rename(columns={' Perioade': 'Év'}, inplace=True)
df.rename(columns={' Valoare': 'Átlagos havi fogyasztás (kg)'}, inplace=True)

# %%
df['Év'] = df['Év'].astype(int)

# %%
df.to_excel('fogyasztasMakroregio.xlsx')
df.to_csv('fogyasztasMakroregio.csv')

# %%
df.drop('Coordinates', axis=1, inplace=True)

# %%
df['Makrorégiók'] = df['Makrorégiók'].str.replace('MACROREGIUNEA UNU', '1-es Makrorégió')
df['Makrorégiók'] = df['Makrorégiók'].str.replace('MACROREGIUNEA DOI', '2-es Makrorégió')
df['Makrorégiók'] = df['Makrorégiók'].str.replace('MACROREGIUNEA TREI', '3-as Makrorégió')
df['Makrorégiók'] = df['Makrorégiók'].str.replace('MACROREGIUNEA PATRU', '4-es Makrorégió')

# %%
df['Makrorégiók'] = df['Makrorégiók'].str.replace('1-es Makrorégió', '1-es Makrorégió')
df['Makrorégiók'] = df['Makrorégiók'].str.replace('2-es Makrorégió\t', '2-es Makrorégió')
df['Makrorégiók'] = df['Makrorégiók'].str.replace('3-as Makrorégió', '3-as Makrorégió')
df['Makrorégiók'] = df['Makrorégiók'].str.replace('4-es Makrorégió\t', '4-es Makrorégió')

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# mézrégióbol a makroregiok kiszedése

# %%
df1=pd.read_excel('mezregio (1).xlsx')

# %%
df1=df1[df1['Régiók, fejlesztési régiók és makrorégiók'].isin(['1-es Makrorégió','2-es Makrorégió','3-as Makrorégió', '4-es Makrorégió'])]

# %%
df1.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-6038343c88fa> in <cell line: 1>()
# ----> 1 df1.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'],inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
df1.rename(columns={'Régiók, fejlesztési régiók és makrorégiók': 'Makrorégiók'}, inplace=True)
# Out:
# <ipython-input-9-717cfe01a8d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={'Régiók, fejlesztési régiók és makrorégiók': 'Makrorégiók'}, inplace=True)

# %%
df1.reset_index(drop=True, inplace=True)

# %% [markdown]
# méhrégiobol a makroregiok kiszedése

# %%
df2=pd.read_excel('mehregio (3).xlsx')

# %%
df2=pd.read_excel('mezregio.xlsx')

# %%
df2.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df2=df2[df2['Régiók, fejlesztési régiók és makrorégiók'].isin(['1-es Makrorégió','2-es Makrorégió','3-as Makrorégió', '4-es Makrorégió'])]

# %%
df2.rename(columns={'Régiók, fejlesztési régiók és makrorégiók': 'Makrorégiók'}, inplace=True)

# %%
df2.reset_index(drop=True, inplace=True)

# %% [markdown]
# összekapcsolás

# %%
df.sort_values(by=['Év','Makrorégiók'], inplace=True)
df1.sort_values(by=['Év','Makrorégiók'], inplace=True)
df2.sort_values(by=['Év','Makrorégiók'], inplace=True)
# Out:
# <ipython-input-26-b5a360294753>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.sort_values(by=['Év','Makrorégiók'], inplace=True)

# %%
merged_df = pd.merge(df1, df2, on=['Makrorégiók', 'Év'])
#merged_df = pd.merge(merged_df, df, on=['Makrorégiók', 'Év'])

# %%
df
# Out:
#          Makrorégiók    Év  Átlagos havi fogyasztás (kg)
# 0    1-es Makrorégió  2008                         0.067
# 1    2-es Makrorégió  2008                         0.041
# 2    3-as Makrorégió  2008                         0.046
# 3    4-es Makrorégió  2008                         0.044
# 4    1-es Makrorégió  2009                         0.070
# 5    2-es Makrorégió  2009                         0.047
# 6    3-as Makrorégió  2009                         0.050
# 7    4-es Makrorégió  2009                         0.054
# 8    1-es Makrorégió  2010                         0.071
# 9    2-es Makrorégió  2010                         0.047
# 10   3-as Makrorégió  2010                         0.054
# 11   4-es Makrorégió  2010                         0.060
# 12   1-es Makrorégió  2011                         0.070
# 13   2-es Makrorégió  2011                         0.045
# 14   3-as Makrorégió  2011                         0.057
# ...

# %%
merged_df = pd.merge(df1, df2)
#merged_df = pd.merge(merged_df, df)

# %%
df55 = pd.merge(merged_df, df)

# %%
df3= pd.concat([merged_df,df], axis=1)

# %%
df3
# Out:
#     Unnamed: 0      Makrorégiók  Méhcsaládok száma    Év  Kinyert méz  \
# 0            0  1-es Makrorégió             271987  2008         5507
# 1           15  2-es Makrorégió             266741  2008         5824
# 2           30  3-as Makrorégió             172748  2008         3134
# 3           42  4-es Makrorégió             286883  2008         5572
# 4           54  1-es Makrorégió             283269  2009         5628
# 5           69  2-es Makrorégió             279864  2009         5097
# 6           84  3-as Makrorégió             180814  2009         2997
# 7           96  4-es Makrorégió             313239  2009         6215
# 8          108  1-es Makrorégió             354315  2010         5662
# 9          123  2-es Makrorégió             331214  2010         6544
# 10         138  3-as Makrorégió             212291  2010         3817
# 11         150  4-es Makrorégió             377097  2010         6199
# ...

# %%
df_clean = df3.drop_duplicates(subset=['Makrorégiók', 'Év'])

# %%
dfigen= df3.drop_duplicates(subset=["Makrorégiók", "Év"], keep="first")

# %%
dfigen.drop(columns=['Év_6', 'Makrorégiók_5', 'Unnamed: 0'],inplace=True)

# %%
dfigen=df3

# %%
dfigen.columns = [f"{col}_{i}" if i > 0 else col for i, col in enumerate(dfigen.columns)]

# %%
dfigen.rename(columns={'Makrorégiók_1': 'Makrorégiók'}, inplace=True)
dfigen.rename(columns={'Kinyert méz_4': 'Kinyert méz'}, inplace=True)
dfigen.rename(columns={'Év_3': 'Év'}, inplace=True)
dfigen.rename(columns={'Méhcsaládok száma_2': 'Méhcsaládok száma'}, inplace=True)
dfigen.rename(columns={'Átlagos havi fogyasztás (kg)_7': 'Átlagos havi fogyasztás (kg)'}, inplace=True)

# %%
dfigen.rename(columns={'Kinyert méz': 'Év'}, inplace=True)
dfigen.rename(columns={'Év':'Kinyert méz'}, inplace=True)

# %%
dfigen["Év"], dfigen["Kinyert méz"] = dfigen["Kinyert méz"], dfigen["Év"]

# %%
dfigen.to_excel('makroregio.xlsx')
dfigen.to_csv('makroregio.csv')

# %%
dfigen
# Out:
#         Makrorégiók  Méhcsaládok száma    Év  Kinyert méz  \
# 0   1-es Makrorégió             271987  2008         5507
# 1   2-es Makrorégió             266741  2008         5824
# 2   3-as Makrorégió             172748  2008         3134
# 3   4-es Makrorégió             286883  2008         5572
# 4   1-es Makrorégió             283269  2009         5628
# 5   2-es Makrorégió             279864  2009         5097
# 6   3-as Makrorégió             180814  2009         2997
# 7   4-es Makrorégió             313239  2009         6215
# 8   1-es Makrorégió             354315  2010         5662
# 9   2-es Makrorégió             331214  2010         6544
# 10  3-as Makrorégió             212291  2010         3817
# 11  4-es Makrorégió             377097  2010         6199
# 12  1-es Makrorégió             347757  2011         6625
# 13  2-es Makrorégió             321347  2011         6420
# 14  3-as Makrorégió             202574  2011         3533
# ...

# %%
~df1['Makrorégiók'].isin(df['Makrorégiók'])
# Out:
# 1      True
# 16     True
# 31     True
# 43     True
# 56     True
# 71     True
# 86     True
# 98     True
# 111    True
# 126    True
# 141    True
# 153    True
# 166    True
# 181    True
# 196    True
# 208    True
# 221    True
# 236    True
# 251    True
# 263    True
# 276    True
# 291    True
# 306    True
# 318    True
# 331    True
# 346    True
# 361    True
# 373    True
# 386    True
# 441    True
# 401    True
# 456    True
# 416    True
# 471    True
# 428    True
# 483    True
# 496    True
# 511    True
# 526    True
# 538    True
# 551    True
# 566    True
# 581    True
# 593    True
# 606    True
# 621    True
# 636    True
# 648    True
# 661    True
# 676    True
# 691    True
# 703    True
# 716    True
# 731    True
# 746    True
# 758    True
# 771    True
# 786    True
# 801    True
# 813    True
# Name: Makrorégiók, dtype: bool

# %%
df = pd.read_excel('fogyasztasMakroregio.xlsx')
df1 = pd.read_excel('mehregio (3).xlsx')
df2 = pd.read_excel('mezregio.xlsx')

# %% [markdown]
# ne nézd lejjebb        geokodolas probalkozas

# %%
import geopandas as gpd

# %%
import geopandas as gpd

# %%
romania = gpd.read_file('ro_uat_poligon.geojson')

# %%
rom = gpd.read_file('romania-with-regions_.geojson')

# %%
ro= gpd.read_file('ro.json')

# %%
dfjo=df

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="geoapiExercises")
df['Coordinates'] = df['Makrorégiók'].apply(lambda x: geolocator.geocode(x + ", Romania").point if geolocator.geocode(x + ", Romania") else None)
# Out:
# ---------------------------------------------------------------------------
# AdapterHTTPError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/geopy/geocoders/base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     367             if is_json:
# --> 368                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369             else:
#
# /usr/local/lib/python3.10/dist-packages/geopy/adapters.py in get_json(self, url, timeout, headers)
#     446     def get_json(self, url, *, timeout, headers):
# --> 447         resp = self._request(url, timeout=timeout, headers=headers)
#     448         try:
#
# /usr/local/lib/python3.10/dist-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     474             if resp.status_code >= 400:
# --> 475                 raise AdapterHTTPError(
#     476                     "Non-successful status code %s" % resp.status_code,
# ...

# %%
import time

# %%
geolocator = Nominatim(user_agent="geoapiExercises")
df['Coordinates'] = None  # Alapértelmezetten None értéket adunk minden sorhoz

for index, row in df.iterrows():
    location = None
    while location is None:  # Addig próbálkozunk, amíg sikerrel nem járunk
        try:
            location = geolocator.geocode(row['Makrorégiók'] + ", Romania")
            if location:
                df.at[index, 'Coordinates'] = location.point
            else:
                df.at[index, 'Coordinates'] = None
        except Exception as e:
            print("Hiba történt:", str(e))
            pass
        time.sleep(1)  # 1 másodperces késleltetés a következő kérés előtt
# Out:
# Hiba történt: Non-successful status code 403
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=+MACROREGIUNEA+UNU%2C+Romania&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=+MACROREGIUNEA+UNU%2C+Romania&format=json&limit=1
# Hiba történt: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=+MACROREGIUNEA+UNU%2C+Romania&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# ...

# %%
ro
# Out:
#                     source    id             name  \
# 0   https://simplemaps.com  ROSM        Satu Mare
# 1   https://simplemaps.com  ROAR             Arad
# 2   https://simplemaps.com  ROBH            Bihor
# 3   https://simplemaps.com  ROTM            Timis
# 4   https://simplemaps.com  ROMH        Mehedinti
# 5   https://simplemaps.com  RODJ             Dolj
# 6   https://simplemaps.com  ROCL         Calarasi
# 7   https://simplemaps.com  ROTR        Teleorman
# 8   https://simplemaps.com  ROGR          Giurgiu
# 9   https://simplemaps.com  ROCT        Constanta
# 10  https://simplemaps.com  ROOT              Olt
# 11  https://simplemaps.com  ROCS    Caras-Severin
# 12  https://simplemaps.com  ROBT         Botosani
# 13  https://simplemaps.com  ROIS             Iasi
# 14  https://simplemaps.com  ROVS           Vaslui
# 15  https://simplemaps.com  ROGL           Galati
# 16  https://simplemaps.com  ROSV          Suceava
# 17  https://simplemaps.com  ROMM        Maramures
# ...

# %%
df3= pd.read_excel('proba.xlsx')

# %%
df2 = ro.merge(df3, left_on='name', right_on='makroregio')

# %%
df2
# Out:
# Empty GeoDataFrame
# Columns: [source, id, name, geometry, makroregio, syam1, syam2]
# Index: []
