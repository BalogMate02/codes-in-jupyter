# %%
import pandas as pd

# %%
#df5 = pd.read_excel('mézrégió 2005.xls')
#df6 = pd.read_excel('mézrégió 2006.xls')
#df7 = pd.read_excel('mézrégió 2007.xls')nincs
df8 = pd.read_excel('mézrégió 2008.xls')
df9 = pd.read_excel('mézrégió 2009.xls')
df10 = pd.read_excel('mézrégió 2010.xls')
df11 = pd.read_excel('mézrégió 2011.xls')
df12 = pd.read_excel('mézrégió 2012.xls')
df13 = pd.read_excel('mézrégió 2013.xls')
df14 = pd.read_excel('mézrégió 2014.xls')
df15 = pd.read_excel('mézrégió 2015.xls')
df16 = pd.read_excel('mézrégió 2016.xls')
df17 = pd.read_excel('mézrégió 2017.xls')
df18 = pd.read_excel('mézrégió 2018.xls')
df19 = pd.read_excel('mézrégió 2019.xls')
df20 = pd.read_excel('mézrégió 2020.xls')
df21 = pd.read_excel('mézrégió 2021.xls')
df22 = pd.read_excel('mézrégió 2022.xls')

# %%
df8.rename(columns={'14.35 PRODUCŢIA AGRICOLĂ ANIMALĂ, PE MACROREGIUNI, REGIUNI DE DEZVOLTARE ŞI JUDEŢE, ÎN ANUL 2008 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df9.rename(columns={'14.35 PRODUCŢIA AGRICOLĂ ANIMALĂ, ÎN PROFIL TERITORIAL, ÎN ANUL 2009 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df10.rename(columns={'14.35 Producţia agricolă animală, în profil teritorial, în anul 2010 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df11.rename(columns={'14.35 Producţia agricolă animală, în profil teritorial, în anul 2011 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df12.rename(columns={'14.35 Producţia agricolă animală, în profil teritorial, în anul 2012 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df13.rename(columns={'14.35 Producţia agricolă animală, în profil teritorial, în anul 2013 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df14.rename(columns={'14.35 Producţia agricolă animală, în profil teritorial, în anul 2014 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df15.rename(columns={'14.36 Producţia agricolă animală, în profil teritorial, în anul 2015 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df16.rename(columns={'14.36 Producţia agricolă animală, în profil teritorial, în anul 2016 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df17.rename(columns={'14.36 Producţia agricolă animală, în profil teritorial, în anul 2017 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df18.rename(columns={'14.33 Producţia agricolă animală, în profil teritorial, în anul 2018 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df19.rename(columns={'14.33 Producţia agricolă animală, în profil teritorial, în anul 2019 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df20.rename(columns={'14.33 Producţia agricolă animală, în profil teritorial, în anul 2020 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df21.rename(columns={'14.33 Producţia agricolă animală, în profil teritorial, în anul 2021 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)
df22.rename(columns={'14.33 Producţia agricolă animală, în profil teritorial, în anul 2022 - continuare.2': 'Régiók, fejlesztési régiók és makrorégiók'}, inplace=True)

# %% [markdown]
# kiválasztja a szukseges oszlopokat,
# kitörli a fölösleges sorokat,
# átnevezi az egyik oszlopot,
# beszúrja az év oszlopot

# %%
df1 = df8.iloc[:, [-5, -2]]
df1.columns = ['Régiók, fejlesztési régiók és makrorégiók', 'Kinyert méz']
df1 = df1.dropna(axis=1, how='all')
df1 = df1.dropna(axis=0, how='all')
df1 = df1.drop(df1.index[:4])
#df1 = df1.rename(columns={'Unnamed: 22':'Kinyert méz'})
df1['Év'] = 2008

# %% [markdown]
# cserélgetni kell a dfxx-et és az évszámot

# %%
df2 = df22.iloc[:, [-5, -2]]
df2.columns = ['Régiók, fejlesztési régiók és makrorégiók', 'Kinyert méz']
df2 = df2.dropna(axis=1, how='all')
df2 = df2.dropna(axis=0, how='all')
df2 = df2.drop(df2.index[:4])
#df2 = df2.rename(columns={'Unnamed: 22':'Kinyert méz'})
df2['Év'] = 2022

# %%
df1 = pd.concat([df1.reset_index(drop=True),df2.reset_index(drop=True)], axis=0)

# %%
df3=df1 #2014

# %%
df4=df1 #vegig

# %%
df1 = df1[pd.to_numeric(df1['Kinyert méz'], errors='coerce').notnull()]

# %%
df1.to_excel('mezregio.xlsx')
df1.to_csv('mezregio.csv')

# %%
df1
# Out:
#    Régiók, fejlesztési régiók és makrorégiók Kinyert méz    Év
# 0                                      TOTAL       20037  2008
# 1            MACROREGIUNEA 1 / MACROREGION 1        5507  2008
# 2                 Nord - Vest / North - West        2525  2008
# 3                                      Bihor         648  2008
# 4                            Bistriţa-Năsăud         211  2008
# ..                                       ...         ...   ...
# 50                               Vest / West        3330  2022
# 51                                      Arad         623  2022
# 52                             Caraş-Severin        1162  2022
# 53                                 Hunedoara         827  2022
# 54                                     Timiş         718  2022
#
# [825 rows x 3 columns]

# %%
df1 = pd.read_excel('mezregio (1).xlsx')

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA 1 / MACROREGION 1', '1-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Nord - Vest / North - West', 'Északnyugat')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Bihor', 'Bihar')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Bistriţa-Năsăud', 'Beszterce-Naszód')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Cluj', 'Kolozs')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Maramureş', 'Máramaros')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Satu Mare', 'Szatmár')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Sălaj', 'Szilágy')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Centru / Center', 'Közép')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Alba', 'Fehér')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Braşov', 'Brassó')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Covasna', 'Kovászna')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Harghita', 'Hargita')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Mureş', 'Maros')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Sibiu', 'Szeben')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA 2 / MACROREGION 2', '2-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Nord - Est / North - East', 'Északkelet')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Bacău', 'Bákó')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Sud - Est / South - East', 'Délkelet')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA 3 / MACROREGION 3', '3-as Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Sud - Muntenia / South - Muntenia', 'Dél')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Bucureşti - Ilfov / Bucharest - Ilfov', 'Bukarest - Ilfov')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Municipiul Bucureşti / Bucharest Municipality', 'Bukarest')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA 4 / MACROREGION 4', '4-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Sud - Vest Oltenia / South - West Oltenia', 'Délnyugat')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Vest / West', 'Nyugat')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Caraş-Severin', 'Krassó-Szörény')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Hunedoara', 'Hunyad')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Timiş', 'Temes')

# %%
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA UNU / MACROREGION ONE', '1-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA DOI / MACROREGION TWO', '2-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA TREI / MACROREGION THREE', '3-as Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA PATRU / MACROREGION FOUR', '4-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('    Municipiul Bucureşti /  Bucharest Municipality', 'Bukarest')

# %%
df1
# Out:
#    Régiók, fejlesztési régiók és makrorégiók Kinyert méz    Év
# 0                                      TOTAL       20037  2008
# 1                            1-es Makrorégió        5507  2008
# 2                                Északnyugat        2525  2008
# 3                                      Bihar         648  2008
# 4                           Beszterce-Naszód         211  2008
# ..                                       ...         ...   ...
# 50                                    Nyugat        3330  2022
# 51                                      Arad         623  2022
# 52                            Krassó-Szörény        1162  2022
# 53                                    Hunyad         827  2022
# 54                                     Temes         718  2022
#
# [825 rows x 3 columns]
#    Régiók, fejlesztési régiók és makrorégiók Kinyert méz    Év
# 0                                      TOTAL       20037  2008
# ...

# %%
cdf1 = pd.concat([ df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22], axis=1)
cdf1 = cdf1.dropna(axis=1, how='all')
cdf1=cdf1.dropna(axis=0, how='all')

# %%
df1 = df8.iloc[:, [-5, -2, -1]]
df1 = df.dropna(axis=1, how='all')
df1 = df.dropna(axis=0, how='all')

# %%
df = df22.iloc[:, [-5, -2, -1]]
df = df.dropna(axis=1, how='all')
df = df.dropna(axis=0, how='all')
#df1 = df1.set_index(df1.index[0])
#df = df.set_index(df.index[0])
df1 = pd.merge(df1, df, left_index=True, right_index=True, suffixes=('_rurr', '_ar'))

# %%
df1.to_excel('mezregio.xlsx')

# %% [markdown]
# mézrégióba 2016 betevése kiderult, hogy az evek csusztak el

# %%
df=pd.read_excel('mezregio (1).xlsx')

# %%
df1=pd.read_excel('mézrégió 2016.xls')

# %%
df.drop(columns=['Unnamed: 0.1'],inplace=True)

# %%
df1
# Out:
#     Régiók, fejlesztési régiók és makrorégiók Kinyert méz    Év
# 0                                       TOTAL       21202  2016
# 1                             1-es Makrorégió        5938  2016
# 2                                 Északnyugat        2821  2016
# 3                                       Bihar         705  2016
# 4                            Beszterce-Naszód         364  2016
# ..                                        ...         ...   ...
# 820                                    Nyugat        3330  2022
# 821                                      Arad         623  2022
# 822                            Krassó-Szörény        1162  2022
# 823                                    Hunyad         827  2022
# 824                                     Temes         718  2022
#
# [880 rows x 3 columns]
