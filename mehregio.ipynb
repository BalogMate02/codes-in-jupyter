# %%
import pandas as pd

# %%
df8 = pd.read_excel('méhrégió 2008.xls')
df9 = pd.read_excel('méhrégió 2009.xls')
df10 = pd.read_excel('méhrégió 2010.xls')
df11 = pd.read_excel('méhrégió 2011.xls')
df12 = pd.read_excel('méhrégió 2012.xls')
df13 = pd.read_excel('méhrégió 2013.xls')
df14 = pd.read_excel('méhrégió 2014.xls')
df15 = pd.read_excel('méhrégió 2015.xls')
df16 = pd.read_excel('méhrégió 2016.xls')
df17 = pd.read_excel('méhrégió 2017.xls')
df18 = pd.read_excel('méhrégió 2018.xls')
df19 = pd.read_excel('méhrégió 2019.xls')
df20 = pd.read_excel('méhrégió 2020.xls')
df21 = pd.read_excel('méhrégió 2021.xls')
df22 = pd.read_excel('méhrégió 2022.xls')

# %%
df1 = df8.iloc[:, [0, -2]]
df1.columns = ['Régiók, fejlesztési régiók és makrorégiók', 'Méhcsaládok száma']
df1 = df1.dropna(axis=1, how='all')
df1 = df1.dropna(axis=0, how='all')
df1 = df1.drop(df1.index[:4])
df1['Év'] = 2008

# %%
df2 = df2.iloc[:, [0, -2]]
df2.columns = ['Régiók, fejlesztési régiók és makrorégiók', 'Méhcsaládok száma']
df2 = df2.dropna(axis=1, how='all')
df2 = df2.dropna(axis=0, how='all')
df2 = df2.drop(df2.index[:4])
df2['Év'] = 2012

# %%
df1 = pd.concat([df1.reset_index(drop=True),df2.reset_index(drop=True)], axis=0)

# %%
df3=df1

# %%
df1=df3

# %%
df1 = df1[pd.to_numeric(df1['Méhcsaládok száma'], errors='coerce').notna()]

# %%
df1=df1[~df1['Régiók, fejlesztési régiók és makrorégiók'].apply(lambda x: 'din care: proprietate majoritar privată' in x)]

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA 1', '1-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Nord - Vest - total', 'Északnyugat')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Bihor - total', 'Bihar')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Bistriţa-Năsăud - total', 'Beszterce-Naszód')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Cluj - total', 'Kolozs')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Maramureş - total', 'Máramaros')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Satu Mare - total', 'Szatmár')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Sălaj - total', 'Szilágy')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Centru - total', 'Közép')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Alba - total', 'Fehér')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Braşov - total', 'Brassó')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Covasna - total', 'Kovászna')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Harghita - total', 'Hargita')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Mureş - total', 'Maros')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Sibiu - total', 'Szeben')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA 2', '2-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Nord - Est - total', 'Északkelet')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Bacău - total', 'Bákó')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Sud - Est - total', 'Délkelet')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA 3', '3-as Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Sud - Muntenia - total', 'Dél')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Bucureşti - Ilfov - total', 'Bukarest - Ilfov')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Municipiul Bucureşti - total', 'Bukarest')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA 4', '4-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Sud - Vest Oltenia - total', 'Délnyugat')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Vest - total', 'Nyugat')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Caraş-Severin - total', 'Krassó-Szörény')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Hunedoara - total', 'Hunyad')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Timiş - total', 'Temes')
# Out:
# <ipython-input-11-d1930eba60bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA 1', '1-es Makrorégió')
# <ipython-input-11-d1930eba60bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('Nord - Vest - total', 'Északnyugat')
# ...

# %%
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA UNU', '1-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA DOI', '2-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA TREI', '3-as Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA PATRU', '3-es Makrorégió')
df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('3-es Makrorégió', '4-es Makrorégió')
# Out:
# <ipython-input-12-efa92553b433>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA UNU', '1-es Makrorégió')
# <ipython-input-12-efa92553b433>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Régiók, fejlesztési régiók és makrorégiók'] = df1['Régiók, fejlesztési régiók és makrorégiók'].str.replace('MACROREGIUNEA DOI', '2-es Makrorégió')
# ...

# %%
df1.to_excel('mehregio.xlsx')
df1.to_csv('mehregio.csv')

# %% [markdown]
# kiveszi atotalt ha jol megformázom

# %%
for column in df10.select_dtypes(include='object').columns:
    df10[column] = df10[column].str.replace('Anul', '').str.strip()

# %% [markdown]
# 2012-es év hozzáadása a táblázathoz (kimaradt) A többit a fenti utasításokkal csináltam

# %%
df1=pd.read_excel('mehregio (2).xlsx')
df2=pd.read_excel('méhrégió 2012.xls')

# %%
df1.drop(columns=['Unnamed: 0'],inplace=True)
# Out:
# <ipython-input-14-56cb56ceb45b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df1
# Out:
#     Régiók, fejlesztési régiók és makrorégiók Méhcsaládok száma    Év
# 0                             1-es Makrorégió            271987  2008
# 1                                 Északnyugat            126541  2008
# 2                                       Bihar             32229  2008
# 3                            Beszterce-Naszód             18416  2008
# 4                                      Kolozs             18742  2008
# ..                                        ...               ...   ...
# 809                                    Nyugat            168157  2012
# 810                              Arad - total             37743  2012
# 811                            Krassó-Szörény             55984  2012
# 812                                    Hunyad             39904  2012
# 813                                     Temes             34526  2012
#
# [810 rows x 3 columns]
